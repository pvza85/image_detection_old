# %%
import numpy as np
path = '/home/payam/workspace/image_detection/results/cd_covers/Droid/'
caffe_file = 'features_bvlc_googlenet_pool57x7_s1_0.txt'
tf_file = 'features_googlenet_pool5_7x7_s10_20160727203048.txt'

# %%
caffe = np.loadtxt(path+caffe_file)
tf = np.loadtxt(path+tf_file)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(caffe[0][:20])

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
start = 150
end = 200
ax1.plot(caffe[59][start:end])
ax1.plot(tf[59][start:end])

# %%
for i in range(len(caffe)):
    print '{0}: {1}'.format(i, np.cov(caffe[i], tf[1]))
    
#np.cov(caffe, tf)
# Out:
# 0: [[ 0.994521    0.19525759]
#  [ 0.19525759  0.5569554 ]]
# 1: [[ 1.15348091  0.2118177 ]
#  [ 0.2118177   0.5569554 ]]
# 2: [[ 1.11171911  0.34266327]
#  [ 0.34266327  0.5569554 ]]
# 3: [[ 0.70970878  0.4739395 ]
#  [ 0.4739395   0.5569554 ]]
# 4: [[ 0.95291713  0.17166993]
#  [ 0.17166993  0.5569554 ]]
# 5: [[ 0.8743964   0.30453074]
#  [ 0.30453074  0.5569554 ]]
# 6: [[ 0.54776075  0.11765503]
#  [ 0.11765503  0.5569554 ]]
# 7: [[ 0.93066034  0.21588926]
#  [ 0.21588926  0.5569554 ]]
# 8: [[ 0.83114467  0.13650144]
#  [ 0.13650144  0.5569554 ]]
# 9: [[ 0.49672632  0.1308346 ]
#  [ 0.1308346   0.5569554 ]]
# 10: [[ 0.87755818  0.18100251]
#  [ 0.18100251  0.5569554 ]]
# 11: [[ 0.85649477  0.19031472]
#  [ 0.19031472  0.5569554 ]]
# 12: [[ 1.05417936  0.24473903]
#  [ 0.24473903  0.5569554 ]]
# 13: [[ 0.95246307  0.26082316]
#  [ 0.26082316  0.5569554 ]]
# 14: [[ 0.75514036  0.13786123]
#  [ 0.13786123  0.5569554 ]]
# 15: [[ 0.58772384  0.17473842]
#  [ 0.17473842  0.5569554 ]]
# ...
